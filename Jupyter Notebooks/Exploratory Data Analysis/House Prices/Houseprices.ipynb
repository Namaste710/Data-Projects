# %% [markdown]
# # Variables and Imports

# %%
TRAIN_PATH = 'data/train.csv'
TEST_PATH = 'data/test.csv'
import pandas as pd
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
limitNA = len(train_df) * .80
train_df = train_df.dropna(thresh=limitNA, axis=1)
test_df = test_df.dropna(thresh=limitNA, axis=1)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
from sklearn.preprocessing import LabelEncoder
def add_cat_cols(input_df):
    non_numeric_columns = input_df.select_dtypes(exclude=['int64', 'float64']).columns
    numeric_columns = input_df.select_dtypes(include=['int64', 'float64']).columns
    le = LabelEncoder()
    non_numeric_columns = input_df.select_dtypes(exclude=['int64', 'float64']).columns
    numeric_columns = input_df.select_dtypes(include=['int64', 'float64']).columns
    cat_df = input_df[non_numeric_columns].fillna('Empty') # muss auf jeden Fall woanders hin
    for column in non_numeric_columns:
        input_df[column + '_Cat'] = le.fit_transform(cat_df[column])
    transformed_non_numeric_columns = [col for col in input_df.columns if '_Cat' in col]
    selected_cols = numeric_columns.to_list()
    selected_cols.extend(transformed_non_numeric_columns)
    input_df.drop(columns=[col for col in input_df if col not in selected_cols], inplace=True)
    return input_df

# %%
train_df = add_cat_cols(train_df)

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
X_train = train_df.iloc[:, :-1].values
y_train = train_df.iloc[:, -1:].values

# %%
X_train = imp_mean.fit_transform(X_train)
y_train = imp_mean.fit_transform(y_train)

# %%
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize': (20, 12)})

# %%
lr_model = LinearRegression()

lr_model.fit(X_train, y_train)

importance = lr_model.coef_

print(importance)
# Out:
# [[-9.67509100e-03  5.42666599e-02  5.30705070e-02  2.97567318e-02
#   -5.34759436e-02  7.25724986e-02  3.68707294e-02  7.85313117e-02
#    3.03184481e-02  2.20985003e+10  7.81611252e+09  2.14089847e+10
#   -2.12557999e+10 -6.79961127e+10 -7.67800782e+10 -8.55221261e+09
#    9.24256511e+10 -2.72335176e-02 -4.08629770e-02  5.00625600e-02
#    6.25091264e-02 -8.77664589e-03 -1.82557269e-02  4.23867140e-02
#    8.25527588e-02  7.51285378e-02 -1.17007015e-01  1.26905722e-01
#   -3.69178762e-02 -7.20558543e-03 -3.20303595e-02 -1.52785735e-02
#   -3.12898545e-02 -6.34005126e-02  1.49066378e-04  2.15794714e-02
#   -7.27045937e-04  2.29434792e-01  7.77914357e-02 -1.62981079e-02
#    1.60160518e-02 -7.04279747e-03 -4.24027949e-02  5.60255180e-02
#   -5.83834723e-02 -9.98054883e-03  1.72284218e-02  4.26373636e-02
#   -2.08606224e-02 -5.21325621e-02  4.86593324e-02 -2.60050500e-02
#   -2.32356915e-02  2.77195567e-02  9.31195858e-02 -4.66499311e-02
# ...

# %%
feature_importances = pd.DataFrame({'Feature': train_df.columns.drop('Id').to_list(), 'Importance value': importance.flatten()})

# %%
feature_importances.sort_values('Importance value', ascending=False, inplace=True)

# %%
top15 = feature_importances.nlargest(15, 'Importance value')
top12 = feature_importances.nlargest(12, 'Importance value')
top9 = feature_importances.nlargest(9, 'Importance value')

# %%
sns.barplot(top15['Feature'], top15['Importance value'])
# Out:
# C:\Users\HoaiN\Coding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Feature', ylabel='Importance value'>

# %%
sns.barplot(top12['Feature'], top12['Importance value'])
# Out:
# C:\Users\HoaiN\Coding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Feature', ylabel='Importance value'>

# %%
sns.barplot(top9['Feature'], top9['Importance value'])
# Out:
# C:\Users\HoaiN\Coding\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Feature', ylabel='Importance value'>

# %%
train_df[list(top9['Feature'])]
# Out:
#       BsmtFullBath  BsmtFinSF2  TotalBsmtSF  BsmtUnfSF  MSZoning_Cat  \
# 0                1           0          856        150             3
# 1                0           0         1262        284             3
# 2                1           0          920        434             3
# 3                1           0          756        540             3
# 4                1           0         1145        490             3
# ...            ...         ...          ...        ...           ...
# 1455             0           0          953        953             3
# 1456             1         163         1542        589             3
# 1457             0           0         1152        877             3
# 1458             1        1029         1078          0             3
# 1459             1         290         1256        136             3
#
#       SaleCondition_Cat  GarageCond_Cat  WoodDeckSF  ExterQual_Cat
# 0                     4               5           0              2
# ...

# %%
picked_cols = list(top9['Feature'])

picked_train_df = train_df[picked_cols]

X_train_top9 = picked_train_df.iloc[:, :-1].values
y_train_top9 = picked_train_df.iloc[:, -1:].values

X_train_top9 = imp_mean.fit_transform(X_train_top9)
y_train_top9 = imp_mean.fit_transform(y_train_top9)

lr_model_2 = LinearRegression()

lr_model_2.fit(X_train_top9, y_train_top9)
# Out:
# LinearRegression()

# %%
test_df = add_cat_cols(test_df)
picked_test_df = test_df[picked_cols]

X_test_top9 = picked_test_df.iloc[:, :-1].values
y_test_top9 = picked_test_df.iloc[:, -1:].values

X_test_top9 = imp_mean.fit_transform(X_test_top9)
y_test_top9 = imp_mean.fit_transform(y_test_top9)

y_pred_top9 = lr_model_2.predict(X_test_top9)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test_top9, y_pred_top9)
# Out:
# 0.41593243247889217

# %%
test_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  Electrical_Cat  \
# ...

# %% [markdown]
# # Test

# %%
# Out:
# Elasticnet model (alpha=0.200000, l1_ratio=0.200000):
#   RMSE: 0.7336400911821402
#   MAE: 0.5643841279275428
#   R2: 0.2373946606358417

# %%
# Out:
# Der Befehl "mlflow" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.
